# %%
import pandas as pd

# %%
red_df = pd.read_csv('/Users/parkjuyong/Desktop/MyPython/wine+quality/winequality-red.csv',
                      sep = ';', header = 0, engine = 'python')

# %%
white_df = pd.read_csv('/Users/parkjuyong/Desktop/MyPython/wine+quality/winequality-white.csv',
                       sep = ';', header = 0, engine = 'python')

# %%
red_df.to_csv('/Users/parkjuyong/Desktop/MyPython/wine+quality/winequality-red2.csv', 
               index = False)

# %%
white_df.to_csv('/Users/parkjuyong/Desktop/MyPython/wine+quality/winequality-white2.csv', 
               index = False)

# %%
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_df.insert(0, column = 'type', value = 'red')

# %%
red_df.head()
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
red_df.shape
# Out:
# (1599, 13)

# %%
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_df.insert(0, column = 'type', value = 'white')

# %%
white_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
white_df.shape
# Out:
# (4898, 13)

# %%
wine = pd.concat([red_df,white_df])

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.to_csv('/Users/parkjuyong/Desktop/MyPython/wine+quality/wine.csv', index = False)

# %%
print(wine.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB
# None

# %%
wine.columns = wine.columns.str.replace(' ','_')

# %%
wine.head()
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wine.columns = [''.join(col.split('-_-_-_-')).strip() for col in wine.columns]
print(wine.columns.tolist())
# Out:
# ['type', 'fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
sorted(wine.quality.unique())
# Out:
# [np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9)]

# %%
wine.quality.value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
wine.groupby("type")["quality"].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
wine.groupby("type")["quality"].mean()
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
wine.groupby("type")["quality"].std()
# Out:
# type
# red      0.807569
# white    0.885639
# Name: quality, dtype: float64

# %%
wine.groupby("type")["quality"].agg(['mean','std'])
# Out:
#            mean       std
# type
# red    5.636023  0.807569
# white  5.877909  0.885639

# %%
# !pip install statsmodels

# %%
from scipy import stats

# %%
from statsmodels.formula.api import ols, glm

# %%
red_wine_quality = wine.loc[wine['type'] == 'red','quality']

# %%
white_wine_quality = wine.loc[wine['type'] == 'white','quality']

# %%
stats.ttest_ind(red_wine_quality, white_wine_quality, equal_var = False)
# Out:
# TtestResult(statistic=np.float64(-10.149363059143164), pvalue=np.float64(8.168348870049682e-24), df=np.float64(2950.750452166697))

# %%
Rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + \
residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + \
density + pH + sulphates + alcohol'

# %%
regression_result = ols(Rformula, data = wine).fit()

# %%
 regression_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Sun, 19 Oct 2025   Prob (F-statistic):               0.00
# Time:                        00:00:45   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
sample1 = wine[wine.columns.difference(['quality', 'type'])]

# %%
sample1 = sample1[0:5][:]

# %%
sample1_predict = regression_result.predict(sample1)

# %%
sample1_predict
# Out:
# 0    4.997607
# 1    4.924993
# 2    5.034663
# 3    5.680333
# 4    4.997607
# dtype: float64

# %%
wine[0:5]['quality']
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
data = {"fixed_acidity" : [8.5, 8.1], "volatile_acidity":[0.8, 0.5], "citric_acid":[0.3, 0.4], "residual_sugar":[6.1, 5.8],
"chlorides":[0.055, 0.04], "free_sulfur_dioxide":[30.0, 31.0], "total_sulfur_dioxide":[98.0, 99], "density":[0.996, 0.91], "pH":[3.25,
3.01], "sulphates":[0.4, 0.35], "alcohol":[9.0, 0.88]}

# %%
sample2 = pd.DataFrame(data, columns= sample1.columns)

# %%
sample2
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0     9.00      0.055          0.3    0.996            8.5
# 1     0.88      0.040          0.4    0.910            8.1
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 30.0  3.25             6.1       0.40                  98.0
# 1                 31.0  3.01             5.8       0.35                  99.0
#
#    volatile_acidity
# 0               0.8
# 1               0.5

# %%
sample2_predict = regression_result.predict(sample2)

# %%
sample2_predict
# Out:
# 0    4.809094
# 1    7.582129
# dtype: float64

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set_style('dark')

# %%
sns.histplot(red_wine_quality, stat='density', kde = True, color = "red", label = 'red wine')
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
sns.histplot(white_wine_quality, stat='density', kde = True, label = 'white wine')
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
plt.title("Quality of Wine Type")
# Out:
# Text(0.5, 1.0, 'Quality of Wine Type')

# %%
 plt.legend()
# Out:
# /var/folders/dc/3dqm8vys2qv2c52_q3sn76xr0000gn/T/ipykernel_5288/3115411188.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.show()

# %%
import statsmodels.api as sm

# %%
others = list(set(wine.columns).difference(set(["quality", "fixed_acidity"])))

# %%
p, resids = sm.graphics.plot_partregress("quality", "fixed_acidity", others, data = wine, ret_coords = True)

# %%
plt.show()

# %%
fig = plt.figure(figsize = (8, 13))

# %%
sm.graphics.plot_partregress_grid(regression_result, fig = fig)

# %%
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.to_csv('/Users/parkjuyong/Desktop/MyPython/titanic.csv', index = False)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].median())

# %%
titanic['embarked'].value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic['embarked'] = titanic['embarked'].fillna('S')

# %%
titanic['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
titanic['embark_town'] = titanic['embark_town'].fillna('Southampton')

# %%
titanic['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
titanic['deck'] = titanic['deck'].fillna('C')

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         891 non-null    category
#  12  embark_town  891 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(1, 2, figsize = (10, 5))

# %%
titanic['survived'][titanic['sex'] == 'male'].value_counts().plot.pie(explode = [0,0.1], autopct = '%1.1f%%', ax = ax[0], shadow = True)
# Out:
# <Axes: ylabel='count'>

# %%
titanic['survived'][titanic['sex'] == 'female'].value_counts().plot.pie(explode = [0,0.1], autopct = '%1.1f%%', ax = ax[1], shadow = True)
# Out:
# <Axes: ylabel='count'>

# %%
ax[0].set_title('Survived (Male)')
# Out:
# Text(0.5, 1.0, 'Survived (Male)')

# %%
ax[1].set_title('Survived (Female)')
# Out:
# Text(0.5, 1.0, 'Survived (Female)')

# %%
plt.show()

# %%
sns.countplot(x='pclass', hue = 'survived', data = titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
plt.title('Pclass vs Survived')
# Out:
# Text(0.5, 1.0, 'Pclass vs Survived')

# %%
plt.show()

# %%
titanic2 = titanic.select_dtypes(include=[int, float,bool])

# %%
titanic2.shape
# Out:
# (891, 8)

# %%
titanic_corr = titanic2.corr(method = 'pearson')

# %%
titanic_corr
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# age        -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# sibsp      -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.247704 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.171647 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.247704  0.171647
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
titanic_corr.to_csv('/Users/parkjuyong/Desktop/MyPython/titanic_corr.csv', index = False)

# %%
titanic['survived'].corr(titanic['adult_male'])
# Out:
# np.float64(-0.5570800422053248)

# %%
titanic['survived'].corr(titanic['fare'])
# Out:
# np.float64(0.2573065223849624)

# %%
sns.pairplot(titanic, hue = 'survived')

# %%
plt.show()

# %%
sns.catplot(x = 'pclass', y = 'survived', hue = 'sex', data = titanic, kind = 'point')

# %%
plt.show()

# %%
def category_age(x):
    if x > 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7

# %%
titanic['age2'] = titanic['age'].apply(category_age)

# %%
titanic['sex'] = titanic['sex'].map({'male':1, 'female':0})

# %%
titanic['family'] = titanic['sibsp'] + titanic['parch'] + 1

# %%
titanic.to_csv('/Users/parkjuyong/Desktop/MyPython/titanic2.csv', index = False)

# %%
heatmap_data = titanic[['survived','sex','age2','family','pclass','fare']]

# %%
colormap = plt.cm.RdBu

# %%
sns.heatmap(heatmap_data.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square
            = True, cmap = colormap, linecolor = 'white', annot = True, annot_kws = {"size":10})
# Out:
# <Axes: >

# %%
plt.show()
